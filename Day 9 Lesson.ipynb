# %% [markdown]
# # Day 9
#
# Expectations for tests/exams, along with hints.

# %% [markdown]
# Be able to load packages you may need, have an idea about which packages come from where. If you don't have your packages, you won't be able to use them.
#
# Hint: Put the packages (exactly) on your "cheat sheet", along with what you might need them for.

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import math

# %% [markdown]
# Be able to load data, after downloading, from BB or other sources.

# %%
crimeDF = pd.read_csv('index-violent-property-and-firearm-rates-by-county-beginning-1990.csv') 
crimeDF
# Out:
#            County  Year  Population  Index Count  Index Rate  Violent Count  \
# 0          Albany  1990    292594.0        14418      4927.6           1524
# 1        Allegany  1990     50470.0         1280      2536.2            146
# 2           Bronx  1990   1200900.0       104729      8720.9          33635
# 3          Broome  1990    212160.0         7480      3525.6            306
# 4     Cattaraugus  1990     84234.0         2578      3060.5            171
# ...           ...   ...         ...          ...         ...            ...
# 1731   Washington  2017     61690.0          474       768.4             72
# 1732        Wayne  2017     90519.0         1473      1627.3            184
# 1733  Westchester  2017    980819.0        11504      1172.9           1942
# 1734      Wyoming  2017     40666.0          345       848.4             71
# 1735        Yates  2017     24910.0          259      1039.7             26
#
# ...

# %% [markdown]
# Be able to subset data by row or column

# %%
crimeDF['Population']
# Out:
# 0        292594.0
# 1         50470.0
# 2       1200900.0
# 3        212160.0
# 4         84234.0
#           ...
# 1731      61690.0
# 1732      90519.0
# 1733     980819.0
# 1734      40666.0
# 1735      24910.0
# Name: Population, Length: 1736, dtype: float64

# %% [markdown]
# Be able to summarize data.  Mean, median, mode, SD, var, covariance, correlation. Explain the meanings behind these things.

# %%
crimeDF['Population'].std()
# Out:
# 516458.4378416079

# %% [markdown]
# Be able to manage simple irritations with data - perhaps spaces in variable names or getting the file as a CSV, XLS, or XLSX format.  I will not be handing you corrupted data or new/special file formats.

# %%
crimeDF['violentCount'] = crimeDF['Violent Count']
crimeDF['firearmCount'] = crimeDF['Firearm Count']
crimeDF['propertyCount'] = crimeDF['Property Count']

# %% [markdown]
# Be able to make figures and charts of various types.

# %%
mySampleScatter = sns.scatterplot(y = crimeDF['violentCount'], x = crimeDF['firearmCount'], data = crimeDF)

# %%
histogramPlot = plt.hist(crimeDF['Population'])

# %% [markdown]
# Be able to run a regression in python and look at the output!

# %%
reg1 = smf.ols('violentCount ~ firearmCount', data = crimeDF).fit()
print(reg1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           violentCount   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                 1.930e+04
# Date:                Wed, 29 Mar 2023   Prob (F-statistic):               0.00
# Time:                        23:04:04   Log-Likelihood:                -14492.
# No. Observations:                1661   AIC:                         2.899e+04
# Df Residuals:                    1659   BIC:                         2.900e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      384.5109     37.273     10.316      0.000     311.404     457.617
# ...

# %% [markdown]
# Be able to find the marginal effect after seeing regression output.

# %% [markdown]
# Be able to tell me how a hypothesis test works and conduct one.

# %% [markdown]
# Be able to determine if a variable is
# significantly different than 0.

# %% [markdown]
# Be able to determine if a variable is significantly different than another number.

# %% [markdown]
# Be able to conduct a t-test.

# %% [markdown]
# Be able to tell me what $R^2$ is.

# %% [markdown]
# Be able to use groupby commands.

# %%
crimeDF.groupby('County').mean()
# Out:
#                Year    Population   Index Count   Index Rate  Violent Count  \
# County
# Albany       2003.5  2.986816e+05  12450.107143  4183.160714    1379.107143
# Allegany     2003.5  5.001454e+04    918.964286  1828.885714     103.642857
# Bronx        2003.5  1.320801e+06  52198.750000  4074.535714   17492.428571
# Broome       2003.5  2.017122e+05   6552.642857  3244.264286     460.464286
# Cattaraugus  2003.5  8.178229e+04   2085.857143  2537.392857     195.357143
# ...             ...           ...           ...          ...            ...
# Washington   2003.5  6.173179e+04   1028.392857  1672.350000     139.285714
# Wayne        2003.5  9.263225e+04   2119.535714  2291.535714     160.428571
# Westchester  2003.5  9.297790e+05  21689.178571  2367.303571    2811.392857
# Wyoming      2003.5  4.278207e+04    831.285714  1926.342857      96.928571
# Yates        2003.5  2.442321e+04    415.714286  1714.978571      28.964286
#
# ...

# %% [markdown]
# Be able to make a function definition.

# %%
def myFunction(x,y):
  out = x+y
  return out

# %%
myFunction(1,3)
# Out:
# 4

# %% [markdown]
# Be able to conduct an F-test.

# %% [markdown]
# Be able to tell me what multicolinearity is and when it is a problem.

# %% [markdown]
# Be able to conduct a VIF test.

# %%
import scipy.stats as st

# %%
#Test if Violentcrime != nonviolent
#H0: The average of Vcrime = 1379
#HA: The average of Vcrime != 1379

# %%
meanV = crimeDF["violentCount"].mean()

# %%
stdV = crimeDF["violentCount"].std()

# %%
n = len(crimeDF["violentCount"])

# %%
t=meanV/(stdV/math.sqrt(n))

# %%
2*(1-st.t.cdf(t, (n-1))) #This is that N-1 subscript, remember why we are doing 2x
# Out:
# 0.0

# %% [markdown]
# The probability that the average of the county's crimes is 1379 (the same as Albany's) is about zero, we reject the null
